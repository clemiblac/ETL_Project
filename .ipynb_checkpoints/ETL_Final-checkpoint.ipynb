# %%
import os
orig_working_directory=os.getcwd()
orig_working_directory
# Out:
# 'C:\\Users\\clemi\\Desktop\\Clementine-GWU-HW\\ETL_Project'

# %%
os.chdir(os.path.join('..'))
curr_working_directory=os.getcwd()
curr_working_directory
# Out:
# 'C:\\Users\\clemi\\Desktop\\Clementine-GWU-HW'

# %% [markdown]
# ## Import Dependencies

# %%
import json
from sqlalchemy import create_engine
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ## Import configuration variables

# %%
from salesforce_config import sf_username, sf_password, sf_security_token
from salesforce_config import remote_db_endpoint, remote_db_port
from salesforce_config import remote_db_name, remote_db_user, remote_db_pwd

# %% [markdown]
# ## Set up simple_salesforce

# %%
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %% [markdown]
# ## Connect to your MySQL database

# %%
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %% [markdown]
# ### Drop Existing records in Student table Salesforce

# %%
student_records = sf.query("SELECT Id FROM Student__c")
recs_to_delete = [{'Id': r['Id']} for r in student_records['records']]
recs_to_delete
# Out:
# []

# %%
sf.bulk.Student__c.delete(recs_to_delete)
# Out:
# []

# %%
#Drop Existing records in Class Participant table Salesforce

# %%
class_part_records = sf.query("SELECT Id FROM ClassParticipant__c")
recs_to_delete = [{'Id': r['Id']} for r in class_part_records['records']]
recs_to_delete
# Out:
# ---------------------------------------------------------------------------
# SalesforceMalformedRequest                Traceback (most recent call last)
# <ipython-input-10-59c822a688cd> in <module>
# ----> 1 class_part_records = sf.query("SELECT Id FROM ClassParticipant__c")
#       2 recs_to_delete = [{'Id': r['Id']} for r in class_part_records['records']]
#       3 recs_to_delete
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\api.py in query(self, query, include_deleted, **kwargs)
#     355         # `requests` will correctly encode the query string passed as `params`
#     356         result = self._call_salesforce('GET', url, name='query',
# --> 357                                        params=params, **kwargs)
#     358
#     359         return result.json(object_pairs_hook=OrderedDict)
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\api.py in _call_salesforce(self, method, url, name, **kwargs)
#     488
#     489         if result.status_code >= 300:
# --> 490             exception_handler(result, name=name)
#     491
#     492         sforce_limit_info = result.headers.get('Sforce-Limit-Info')
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\util.py in exception_handler(result, name)
#      66     exc_cls = exc_map.get(result.status_code, SalesforceGeneralError)
#      67
# ---> 68     raise exc_cls(result.url, result.status_code, name, response_content)
#      69
#      70
#
# SalesforceMalformedRequest: Malformed request https://na111.salesforce.com/services/data/v42.0/query/?q=SELECT+Id+FROM+ClassParticipant__c. Response content: [{'message': "\nSELECT Id FROM ClassParticipant__c\n               ^\nERROR at Row:1:Column:16\nsObject type 'ClassParticipant__c' is not supported. If you are attempting to use a custom object, be sure to append the '__c' after the entity name. Please reference your WSDL or the describe call for the appropriate names.", 'errorCode': 'INVALID_TYPE'}]

# %%
sf.bulk.ClassParticipant__c.delete(recs_to_delete)
# Out:
# ---------------------------------------------------------------------------
# SalesforceMalformedRequest                Traceback (most recent call last)
# <ipython-input-11-25a4c71167a7> in <module>
# ----> 1 sf.bulk.ClassParticipant__c.delete(recs_to_delete)
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\bulk.py in delete(self, data, batch_size, use_serial)
#     257                                        use_serial=use_serial,
#     258                                        operation='delete', data=data,
# --> 259                                        batch_size=batch_size)
#     260         return results
#     261
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\bulk.py in _bulk_operation(self, object_name, operation, data, use_serial, external_id_field, batch_size, wait)
#     214             job = self._create_job(object_name=object_name, operation=operation,
#     215                                    use_serial=use_serial,
# --> 216                                    external_id_field=external_id_field)
#     217             batches = [
#     218                 self._add_batch(job_id=job['id'], data=i, operation=operation)
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\bulk.py in _create_job(self, operation, object_name, use_serial, external_id_field)
#     103         result = call_salesforce(url=url, method='POST', session=self.session,
#     104                                  headers=self.headers,
# --> 105                                  data=json.dumps(payload))
#     106         return result.json(object_pairs_hook=OrderedDict)
#     107
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\util.py in call_salesforce(url, method, session, headers, **kwargs)
#      80
#      81     if result.status_code >= 300:
# ---> 82         exception_handler(result)
#      83
#      84     return result
#
# ~\Anaconda3\lib\site-packages\simple_salesforce\util.py in exception_handler(result, name)
#      66     exc_cls = exc_map.get(result.status_code, SalesforceGeneralError)
#      67
# ---> 68     raise exc_cls(result.url, result.status_code, name, response_content)
#      69
#      70
#
# SalesforceMalformedRequest: Malformed request https://na111.salesforce.com/services/async/42.0/job. Response content: {'exceptionCode': 'InvalidJob', 'exceptionMessage': 'Unable to find object: ClassParticipant__c'}

# %%
#Drop Existing records in Class table Salesforce

# %%
class_records = sf.query("SELECT Id FROM class__c")
recs_to_delete = [{'Id': r['Id']} for r in class_records['records']]
recs_to_delete

# %%
sf.bulk.class__c.delete(recs_to_delete)

# %%
#Drop Existing records in Course table Salesforce

# %%
course_records = sf.query("SELECT Id FROM Course__c")
recs_to_delete = [{'Id': r['Id']} for r in course_records['records']]
recs_to_delete
# Out:
# []

# %%
sf.bulk.Course__c.delete(recs_to_delete)
# Out:
# []

# %%
#Drop Existing records in Staff assignment table Salesforce

# %%
staff_assignment_records = sf.query("SELECT Id FROM StaffAssignment__c")
recs_to_delete = [{'Id': r['Id']} for r in staff_assignment_records['records']]
recs_to_delete

# %%
sf.bulk.StaffAssignment__c.delete(recs_to_delete)

# %%
#Drop Existing records in Staff table Salesforce

# %%
staff_records = sf.query("SELECT Id FROM Staff__c")
recs_to_delete = [{'Id': r['Id']} for r in staff_records['records']]
recs_to_delete

# %%
sf.bulk.Staff__c.delete(recs_to_delete)

# %% [markdown]
# ## Query Data

# %%
#Course data

# %%
course_data = pd.read_sql("SELECT * FROM course", conn)
course_data.head(2)
# Out:
#    ID_Course  CourseCode                        CourseName  CreditHours  \
# 0          1  BC-DATAVIZ  Data Visualization and Analytics           12
# 1          2   BC-WEBDEV        Full Stack Web Development           12
#
#    BootCampCourse
# 0               1
# 1               1

# %%
#Rename Columns

# %%
course_data=course_data.rename(columns={"ID_Course":"Name","CourseCode":"CourseCode__c","CourseName":"CourseName__c",
                                       "CreditHours":"CreditHours__c","BootCampCourse":"BootCampCourse__c"})
course_data.head()
# Out:
#    Name CourseCode__c                     CourseName__c  CreditHours__c  \
# 0     1    BC-DATAVIZ  Data Visualization and Analytics              12
# 1     2     BC-WEBDEV        Full Stack Web Development              12
# 2     3       BC-UIUX    User Interface/User Experience              12
# 3     4       CIS-349         Introduction to Databases               5
# 4     5       CIS-405              Database Programming               5
#
#    BootCampCourse__c
# 0                  1
# 1                  1
# 2                  1
# 3                  0
# 4                  0

# %%
#Convert DataFrame to a list of Dictionaries

# %%
course_load = course_data.to_dict('records')
course_load
# Out:
# [{'Name': 1,
#   'CourseCode__c': 'BC-DATAVIZ',
#   'CourseName__c': 'Data Visualization and Analytics',
#   'CreditHours__c': 12,
#   'BootCampCourse__c': 1},
#  {'Name': 2,
#   'CourseCode__c': 'BC-WEBDEV',
#   'CourseName__c': 'Full Stack Web Development',
#   'CreditHours__c': 12,
#   'BootCampCourse__c': 1},
#  {'Name': 3,
#   'CourseCode__c': 'BC-UIUX',
#   'CourseName__c': 'User Interface/User Experience',
#   'CreditHours__c': 12,
#   'BootCampCourse__c': 1},
#  {'Name': 4,
#   'CourseCode__c': 'CIS-349',
#   'CourseName__c': 'Introduction to Databases',
#   'CreditHours__c': 5,
#   'BootCampCourse__c': 0},
#  {'Name': 5,
#   'CourseCode__c': 'CIS-405',
#   'CourseName__c': 'Database Programming',
#   'CreditHours__c': 5,
#   'BootCampCourse__c': 0},
#  {'Name': 6,
#   'CourseCode__c': 'CIS-438',
#   'CourseName__c': 'Database Administration',
#   'CreditHours__c': 5,
#   'BootCampCourse__c': 0},
#  {'Name': 7,
#   'CourseCode__c': 'CIS-430',
#   'CourseName__c': 'Business Systems Programming I',
#   'CreditHours__c': 5,
#   'BootCampCourse__c': 0},
#  {'Name': 8,
#   'CourseCode__c': 'CIS-435',
#   'CourseName__c': 'Business Systems Programming II',
#   'CreditHours__c': 5,
#   'BootCampCourse__c': 0}]

# %%
#Inserting rows in bulk

# %%
try:
    sf.bulk.Course__c.insert(course_load)
except Exception as e:
    print(e)

# %% [markdown]
# # Class data

# %%
class_data = pd.read_sql("SELECT * FROM class", conn)
class_data.head(5)
# Out:
#    ID_Class  ID_Course               Section   StartDate     EndDate
# 0         1          1  GWU-ARL-DATA-PT-09-0  2020-03-16  2020-03-14
# 1         2          1       GWDC201805DATA3  2018-05-15  2018-11-08
# 2         3          2       GWARL201905WEB3  2019-05-14  2019-11-07
# 3         4          3      GWARL201905UIUX3  2019-05-14  2019-11-07

# %%
class_data=class_data.rename(columns={"ID_Class":"Name","ID_Course":"ID_Course__c","Section":"Section__c",
                                      "StartDate":"StartDate__c","EndDate":"EndDate__c"})

class_data.head(5)
# Out:
#    Name  ID_Course__c            Section__c StartDate__c  EndDate__c
# 0     1             1  GWU-ARL-DATA-PT-09-0   2020-03-16  2020-03-14
# 1     2             1       GWDC201805DATA3   2018-05-15  2018-11-08
# 2     3             2       GWARL201905WEB3   2019-05-14  2019-11-07
# 3     4             3      GWARL201905UIUX3   2019-05-14  2019-11-07

# %%
class_data["StartDate__c"]=class_data["StartDate__c"].astype(str)
class_data["EndDate__c"]=class_data["EndDate__c"].astype(str)

# %%
#Extract Record ID

# %%
course_query=sf.query("SELECT Name from Course__c")

# %%
course_query
# Out:
# OrderedDict([('totalSize', 8),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlUEAQ')])),
#                             ('Name', '1')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlVEAQ')])),
#                             ('Name', '2')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlWEAQ')])),
#                             ('Name', '3')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlXEAQ')])),
#                             ('Name', '4')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlYEAQ')])),
#                             ('Name', '5')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlZEAQ')])),
#                             ('Name', '6')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlaEAA')])),
#                             ('Name', '7')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Course__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Course__c/a0G3h0000011zlbEAA')])),
#                             ('Name', '8')])])])

# %%
course_dict={}
x=0
while x< len(course_query['records']):
    url=course_query['records'][x]['attributes']['url'].split('/')[6]
    course_id=int(course_query['records'][x]['Name'])
    print(url,course_id)
    course_dict[course_id]=url
    x=x+1
print(course_dict)
# Out:
# a0G3h0000011zlUEAQ 1
# a0G3h0000011zlVEAQ 2
# a0G3h0000011zlWEAQ 3
# a0G3h0000011zlXEAQ 4
# a0G3h0000011zlYEAQ 5
# a0G3h0000011zlZEAQ 6
# a0G3h0000011zlaEAA 7
# a0G3h0000011zlbEAA 8
# {1: 'a0G3h0000011zlUEAQ', 2: 'a0G3h0000011zlVEAQ', 3: 'a0G3h0000011zlWEAQ', 4: 'a0G3h0000011zlXEAQ', 5: 'a0G3h0000011zlYEAQ', 6: 'a0G3h0000011zlZEAQ', 7: 'a0G3h0000011zlaEAA', 8: 'a0G3h0000011zlbEAA'}

# %%
for index,row in class_data.iterrows():
    try:
        class_data['ID_Course__c'][index]=course_dict[row['ID_Course__c']]
        
    except KeyError as e:
        print(e)
class_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\clemi\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#    Name        ID_Course__c            Section__c StartDate__c  EndDate__c
# 0     1  a0G3h0000011zlUEAQ  GWU-ARL-DATA-PT-09-0   2020-03-16  2020-03-14
# 1     2  a0G3h0000011zlUEAQ       GWDC201805DATA3   2018-05-15  2018-11-08
# 2     3  a0G3h0000011zlVEAQ       GWARL201905WEB3   2019-05-14  2019-11-07
# 3     4  a0G3h0000011zlWEAQ      GWARL201905UIUX3   2019-05-14  2019-11-07

# %%
class_load = class_data.to_dict('records')
class_load
# Out:
# [{'Name': 1,
#   'ID_Course__c': 'a0G3h0000011zlUEAQ',
#   'Section__c': 'GWU-ARL-DATA-PT-09-0',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': '2020-03-14'},
#  {'Name': 2,
#   'ID_Course__c': 'a0G3h0000011zlUEAQ',
#   'Section__c': 'GWDC201805DATA3',
#   'StartDate__c': '2018-05-15',
#   'EndDate__c': '2018-11-08'},
#  {'Name': 3,
#   'ID_Course__c': 'a0G3h0000011zlVEAQ',
#   'Section__c': 'GWARL201905WEB3',
#   'StartDate__c': '2019-05-14',
#   'EndDate__c': '2019-11-07'},
#  {'Name': 4,
#   'ID_Course__c': 'a0G3h0000011zlWEAQ',
#   'Section__c': 'GWARL201905UIUX3',
#   'StartDate__c': '2019-05-14',
#   'EndDate__c': '2019-11-07'}]

# %%
try:
    sf.bulk.class__c.insert(class_load)
except Exception as e:
    print(e)

# %% [markdown]
# # STUDENT DATA

# %%
#Transform Data

# %%
student_data = pd.read_sql("SELECT * FROM student", conn)
student_data.head(5)
# Out:
#    ID_Student StudentID    LastName  FirstName MiddleName BirthDate Gender
# 0          33  25004961       Moore    Heather      Alice      None      F
# 1          34  25003514      Multak      Ilana    Cecille      None      F
# 2          35  25005833     Murillo    Jessica    Dorothy      None      F
# 3          36  25002589  Romanowski     Kandra  Genevieve      None      F
# 4          37  25007185      Hoffer  Katherine   Lynnette      None      F

# %%
#student_data['FullName'] = student_data['FirstName'].str.cat(student_data['LastName'], sep=" ")
student_data=student_data.rename(columns={"ID_Student":"Name","StudentID":"StudentID__c","LastName":"LastName__c",
                                       "FirstName":"FirstName__c","MiddleName":"MiddleName__c","Gender":"Gender__c",
                                        "BirthDate":"BirthDate__c"})
student_data.head(5)
# Out:
#    Name StudentID__c LastName__c FirstName__c MiddleName__c BirthDate__c  \
# 0    33     25004961       Moore      Heather         Alice         None
# 1    34     25003514      Multak        Ilana       Cecille         None
# 2    35     25005833     Murillo      Jessica       Dorothy         None
# 3    36     25002589  Romanowski       Kandra     Genevieve         None
# 4    37     25007185      Hoffer    Katherine      Lynnette         None
#
#   Gender__c
# 0         F
# 1         F
# 2         F
# 3         F
# 4         F

# %%
#Convert DataFrame to a list of Dictionaries

# %%
student_load = student_data.to_dict('records')
student_load
# Out:
# [{'Name': 33,
#   'StudentID__c': '25004961',
#   'LastName__c': 'Moore',
#   'FirstName__c': 'Heather',
#   'MiddleName__c': 'Alice',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 34,
#   'StudentID__c': '25003514',
#   'LastName__c': 'Multak',
#   'FirstName__c': 'Ilana',
#   'MiddleName__c': 'Cecille',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 35,
#   'StudentID__c': '25005833',
#   'LastName__c': 'Murillo',
#   'FirstName__c': 'Jessica',
#   'MiddleName__c': 'Dorothy',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 36,
#   'StudentID__c': '25002589',
#   'LastName__c': 'Romanowski',
#   'FirstName__c': 'Kandra',
#   'MiddleName__c': 'Genevieve',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 37,
#   'StudentID__c': '25007185',
#   'LastName__c': 'Hoffer',
#   'FirstName__c': 'Katherine',
#   'MiddleName__c': 'Lynnette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 38,
#   'StudentID__c': '25006014',
#   'LastName__c': 'Poocharoen',
#   'FirstName__c': 'Pariya',
#   'MiddleName__c': 'Mariette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 39,
#   'StudentID__c': '25007528',
#   'LastName__c': 'Mantrala',
#   'FirstName__c': 'Sriharitha',
#   'MiddleName__c': 'Patty',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 40,
#   'StudentID__c': '25003778',
#   'LastName__c': 'Kelly',
#   'FirstName__c': 'Carly',
#   'MiddleName__c': 'Raelene',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 41,
#   'StudentID__c': '25003605',
#   'LastName__c': 'Sraha',
#   'FirstName__c': 'Clementine',
#   'MiddleName__c': 'Kendall',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 42,
#   'StudentID__c': '25002056',
#   'LastName__c': 'Abdulrahim',
#   'FirstName__c': 'Jawaher',
#   'MiddleName__c': 'Angela',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 43,
#   'StudentID__c': '25004152',
#   'LastName__c': 'Schulte',
#   'FirstName__c': 'Sarah',
#   'MiddleName__c': 'Serita',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 44,
#   'StudentID__c': '25004097',
#   'LastName__c': 'Damdinsuren',
#   'FirstName__c': 'Undraa',
#   'MiddleName__c': 'Claire',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'Name': 45,
#   'StudentID__c': '25002311',
#   'LastName__c': 'Smith',
#   'FirstName__c': 'James',
#   'MiddleName__c': 'Carlton',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 46,
#   'StudentID__c': '25005602',
#   'LastName__c': 'Martinez',
#   'FirstName__c': 'Joisel',
#   'MiddleName__c': 'Cyrus',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 47,
#   'StudentID__c': '25006805',
#   'LastName__c': 'Odhiambo',
#   'FirstName__c': 'Pius',
#   'MiddleName__c': 'Danny',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 48,
#   'StudentID__c': '25006947',
#   'LastName__c': 'Karr',
#   'FirstName__c': 'Todd',
#   'MiddleName__c': 'Darren',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 49,
#   'StudentID__c': '25002714',
#   'LastName__c': 'Stark',
#   'FirstName__c': 'Tom',
#   'MiddleName__c': 'Deangelo',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 50,
#   'StudentID__c': '25005284',
#   'LastName__c': 'Mahmood',
#   'FirstName__c': 'Adit',
#   'MiddleName__c': 'Dion',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 51,
#   'StudentID__c': '25006348',
#   'LastName__c': 'Mikus',
#   'FirstName__c': 'Chris',
#   'MiddleName__c': 'Floyd',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 52,
#   'StudentID__c': '25002555',
#   'LastName__c': 'Hanafin',
#   'FirstName__c': 'Christopher',
#   'MiddleName__c': 'Horace',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 53,
#   'StudentID__c': '25005250',
#   'LastName__c': 'Fingerut',
#   'FirstName__c': 'Cole',
#   'MiddleName__c': 'Lino',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 54,
#   'StudentID__c': '25002325',
#   'LastName__c': 'Hoff',
#   'FirstName__c': 'David',
#   'MiddleName__c': 'Lucien',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 55,
#   'StudentID__c': '25003773',
#   'LastName__c': 'Molina',
#   'FirstName__c': 'Dino',
#   'MiddleName__c': 'Lynwood',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 56,
#   'StudentID__c': '25003936',
#   'LastName__c': 'Vega',
#   'FirstName__c': 'John',
#   'MiddleName__c': 'Noelle',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 57,
#   'StudentID__c': '25005443',
#   'LastName__c': 'Clarke',
#   'FirstName__c': 'Michael',
#   'MiddleName__c': 'Parker',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 58,
#   'StudentID__c': '25006762',
#   'LastName__c': 'Huynh',
#   'FirstName__c': 'Patrick',
#   'MiddleName__c': 'Richard',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 59,
#   'StudentID__c': '25006027',
#   'LastName__c': 'Oppan',
#   'FirstName__c': 'Robert',
#   'MiddleName__c': 'Riley',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 60,
#   'StudentID__c': '25002876',
#   'LastName__c': 'Doucet',
#   'FirstName__c': 'Trevor',
#   'MiddleName__c': 'Seth',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 61,
#   'StudentID__c': '25007333',
#   'LastName__c': 'Omar',
#   'FirstName__c': 'Yasir',
#   'MiddleName__c': 'Solomon',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'Name': 62,
#   'StudentID__c': '25007334',
#   'LastName__c': 'Williamson',
#   'FirstName__c': 'Kevin',
#   'MiddleName__c': 'Stewart',
#   'BirthDate__c': None,
#   'Gender__c': 'M'}]

# %%
#Inserting rows in bulk

# %%
try:
    sf.bulk.Student__c.insert(student_load) #Student__c is the API name
except Exception as e:
    print(e)

# %% [markdown]
# ### Class participant

# %%
participant_data = pd.read_sql("SELECT * FROM classparticipant", conn)
participant_data.head(4)
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate
# 0                    1          33         1  2020-03-16    None
# 1                    2          34         1  2020-03-16    None
# 2                    3          35         1  2020-03-16    None
# 3                    4          62         1  2020-03-16    None

# %%
participant_data=participant_data.rename(columns={"ID_ClassParticipant":"Name","ID_Student":"ID_Student__c",
                                        "ID_Class":"ID_Class__c","StartDate":"StartDate__c","EndDate":"EndDate__c"})
#convert date to string otherwise we will get JSON nonserilizable error
participant_data["StartDate__c"]=participant_data["StartDate__c"].astype(str)
participant_data.head()
# Out:
#    Name  ID_Student__c  ID_Class__c StartDate__c EndDate__c
# 0     1             33            1   2020-03-16       None
# 1     2             34            1   2020-03-16       None
# 2     3             35            1   2020-03-16       None
# 3     4             62            1   2020-03-16       None
# 4     5             36            1   2020-03-16       None

# %%
#Extract Record ID for student

# %%
student_query=sf.query("SELECT Name from Student__c")
student_query
# Out:
# OrderedDict([('totalSize', 30),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GmEAI')])),
#                             ('Name', '33')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GnEAI')])),
#                             ('Name', '34')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GoEAI')])),
#                             ('Name', '35')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GpEAI')])),
#                             ('Name', '36')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GqEAI')])),
#                             ('Name', '37')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GrEAI')])),
#                             ('Name', '38')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GsEAI')])),
#                             ('Name', '39')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GtEAI')])),
#                             ('Name', '40')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GuEAI')])),
#                             ('Name', '41')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GvEAI')])),
#                             ('Name', '42')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GwEAI')])),
#                             ('Name', '43')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GxEAI')])),
#                             ('Name', '44')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GyEAI')])),
#                             ('Name', '45')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8GzEAI')])),
#                             ('Name', '46')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H0EAI')])),
#                             ('Name', '47')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H1EAI')])),
#                             ('Name', '48')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H2EAI')])),
#                             ('Name', '49')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H3EAI')])),
#                             ('Name', '50')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H4EAI')])),
#                             ('Name', '51')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H5EAI')])),
#                             ('Name', '52')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H6EAI')])),
#                             ('Name', '53')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H7EAI')])),
#                             ('Name', '54')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H8EAI')])),
#                             ('Name', '55')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8H9EAI')])),
#                             ('Name', '56')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HAEAY')])),
#                             ('Name', '57')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HBEAY')])),
#                             ('Name', '58')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HCEAY')])),
#                             ('Name', '59')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HDEAY')])),
#                             ('Name', '60')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HEEAY')])),
#                             ('Name', '61')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c8HFEAY')])),
#                             ('Name', '62')])])])

# %%
student_dict={}
x=0
while x< len(student_query['records']):
    url=student_query['records'][x]['attributes']['url'].split('/')[6]
    student_id=int(student_query['records'][x]['Name'])
    print(url,student_id)
    student_dict[student_id]=url
    x=x+1
print(student_dict)
# Out:
# a0A3h000002c8GmEAI 33
# a0A3h000002c8GnEAI 34
# a0A3h000002c8GoEAI 35
# a0A3h000002c8GpEAI 36
# a0A3h000002c8GqEAI 37
# a0A3h000002c8GrEAI 38
# a0A3h000002c8GsEAI 39
# a0A3h000002c8GtEAI 40
# a0A3h000002c8GuEAI 41
# a0A3h000002c8GvEAI 42
# a0A3h000002c8GwEAI 43
# a0A3h000002c8GxEAI 44
# a0A3h000002c8GyEAI 45
# a0A3h000002c8GzEAI 46
# a0A3h000002c8H0EAI 47
# a0A3h000002c8H1EAI 48
# a0A3h000002c8H2EAI 49
# a0A3h000002c8H3EAI 50
# a0A3h000002c8H4EAI 51
# a0A3h000002c8H5EAI 52
# a0A3h000002c8H6EAI 53
# a0A3h000002c8H7EAI 54
# a0A3h000002c8H8EAI 55
# a0A3h000002c8H9EAI 56
# a0A3h000002c8HAEAY 57
# a0A3h000002c8HBEAY 58
# a0A3h000002c8HCEAY 59
# a0A3h000002c8HDEAY 60
# a0A3h000002c8HEEAY 61
# a0A3h000002c8HFEAY 62
# {33: 'a0A3h000002c8GmEAI', 34: 'a0A3h000002c8GnEAI', 35: 'a0A3h000002c8GoEAI', 36: 'a0A3h000002c8GpEAI', 37: 'a0A3h000002c8GqEAI', 38: 'a0A3h000002c8GrEAI', 39: 'a0A3h000002c8GsEAI', 40: 'a0A3h000002c8GtEAI', 41: 'a0A3h000002c8GuEAI', 42: 'a0A3h000002c8GvEAI', 43: 'a0A3h000002c8GwEAI', 44: 'a0A3h000002c8GxEAI', 45: 'a0A3h000002c8GyEAI', 46: 'a0A3h000002c8GzEAI', 47: 'a0A3h000002c8H0EAI', 48: 'a0A3h000002c8H1EAI', 49: 'a0A3h000002c8H2EAI', 50: 'a0A3h000002c8H3EAI', 51: 'a0A3h000002c8H4EAI', 52: 'a0A3h000002c8H5EAI', 53: 'a0A3h000002c8H6EAI', 54: 'a0A3h000002c8H7EAI', 55: 'a0A3h000002c8H8EAI', 56: 'a0A3h000002c8H9EAI', 57: 'a0A3h000002c8HAEAY', 58: 'a0A3h000002c8HBEAY', 59: 'a0A3h000002c8HCEAY', 60: 'a0A3h000002c8HDEAY', 61: 'a0A3h000002c8HEEAY', 62: 'a0A3h000002c8HFEAY'}

# %%
for index,row in participant_data.iterrows():
    participant_data['ID_Student__c'][index]=student_dict[row['ID_Student__c']]
participant_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Name       ID_Student__c  ID_Class__c StartDate__c EndDate__c
# 0      1  a0A3h000002c8GmEAI            1   2020-03-16       None
# 1      2  a0A3h000002c8GnEAI            1   2020-03-16       None
# 2      3  a0A3h000002c8GoEAI            1   2020-03-16       None
# 3      4  a0A3h000002c8HFEAY            1   2020-03-16       None
# 4      5  a0A3h000002c8GpEAI            1   2020-03-16       None
# 5      6  a0A3h000002c8GqEAI            1   2020-03-16       None
# 6      7  a0A3h000002c8GrEAI            1   2020-03-16       None
# 7      8  a0A3h000002c8GsEAI            1   2020-03-16       None
# 8      9  a0A3h000002c8GtEAI            1   2020-03-16       None
# 9     10  a0A3h000002c8GuEAI            1   2020-03-16       None
# 10    11  a0A3h000002c8GvEAI            1   2020-03-16       None
# 11    12  a0A3h000002c8GwEAI            1   2020-03-16       None
# 12    13  a0A3h000002c8GzEAI            1   2020-03-16       None
# 13    14  a0A3h000002c8H0EAI            1   2020-03-16       None
# 14    15  a0A3h000002c8H1EAI            1   2020-03-16       None
# 15    16  a0A3h000002c8H2EAI            1   2020-03-16       None
# 16    17  a0A3h000002c8H3EAI            1   2020-03-16       None
# 17    18  a0A3h000002c8H4EAI            1   2020-03-16       None
# 18    20  a0A3h000002c8H6EAI            1   2020-03-16       None
# 19    21  a0A3h000002c8H7EAI            1   2020-03-16       None
# 20    22  a0A3h000002c8H8EAI            1   2020-03-16       None
# 21    23  a0A3h000002c8H9EAI            1   2020-03-16       None
# 22    24  a0A3h000002c8HAEAY            1   2020-03-16       None
# 23    25  a0A3h000002c8HBEAY            1   2020-03-16       None
# 24    26  a0A3h000002c8HCEAY            1   2020-03-16       None
# 25    27  a0A3h000002c8HDEAY            1   2020-03-16       None
# 26    28  a0A3h000002c8HEEAY            1   2020-03-16       None
# 27    29  a0A3h000002c8GxEAI            1   2020-03-16       None

# %%
#Obtaining ID_Class record IDs and

# %%
class_query=sf.query("SELECT Name from class__c")
class_query
# Out:
# OrderedDict([('totalSize', 4),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSZEAY')])),
#                             ('Name', '1')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSaEAI')])),
#                             ('Name', '2')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSbEAI')])),
#                             ('Name', '3')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uScEAI')])),
#                             ('Name', '4')])])])

# %%
class_dict={}
x=0
while x< len(class_query['records']):
    url=class_query['records'][x]['attributes']['url'].split('/')[6]
    class_id=int(class_query['records'][x]['Name'])
    print(url,class_id)
    class_dict[class_id]=url
    x=x+1
print(class_dict)
# Out:
# a0F3h0000026uSZEAY 1
# a0F3h0000026uSaEAI 2
# a0F3h0000026uSbEAI 3
# a0F3h0000026uScEAI 4
# {1: 'a0F3h0000026uSZEAY', 2: 'a0F3h0000026uSaEAI', 3: 'a0F3h0000026uSbEAI', 4: 'a0F3h0000026uScEAI'}

# %%
for index,row in participant_data.iterrows():
    try:
        participant_data['ID_Class__c'][index]=class_dict[row['ID_Class__c']]
    except KeyError as e:
        print(e)
participant_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Name       ID_Student__c         ID_Class__c StartDate__c EndDate__c
# 0      1  a0A3h000002c8GmEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 1      2  a0A3h000002c8GnEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 2      3  a0A3h000002c8GoEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 3      4  a0A3h000002c8HFEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 4      5  a0A3h000002c8GpEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 5      6  a0A3h000002c8GqEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 6      7  a0A3h000002c8GrEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 7      8  a0A3h000002c8GsEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 8      9  a0A3h000002c8GtEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 9     10  a0A3h000002c8GuEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 10    11  a0A3h000002c8GvEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 11    12  a0A3h000002c8GwEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 12    13  a0A3h000002c8GzEAI  a0F3h0000026uSZEAY   2020-03-16       None
# 13    14  a0A3h000002c8H0EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 14    15  a0A3h000002c8H1EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 15    16  a0A3h000002c8H2EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 16    17  a0A3h000002c8H3EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 17    18  a0A3h000002c8H4EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 18    20  a0A3h000002c8H6EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 19    21  a0A3h000002c8H7EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 20    22  a0A3h000002c8H8EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 21    23  a0A3h000002c8H9EAI  a0F3h0000026uSZEAY   2020-03-16       None
# 22    24  a0A3h000002c8HAEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 23    25  a0A3h000002c8HBEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 24    26  a0A3h000002c8HCEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 25    27  a0A3h000002c8HDEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 26    28  a0A3h000002c8HEEAY  a0F3h0000026uSZEAY   2020-03-16       None
# 27    29  a0A3h000002c8GxEAI  a0F3h0000026uSZEAY   2020-03-16       None

# %%
participant_load = participant_data.to_dict('records')
participant_load
# Out:
# [{'Name': 1,
#   'ID_Student__c': 'a0A3h000002c8GmEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 2,
#   'ID_Student__c': 'a0A3h000002c8GnEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 3,
#   'ID_Student__c': 'a0A3h000002c8GoEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 4,
#   'ID_Student__c': 'a0A3h000002c8HFEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 5,
#   'ID_Student__c': 'a0A3h000002c8GpEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 6,
#   'ID_Student__c': 'a0A3h000002c8GqEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 7,
#   'ID_Student__c': 'a0A3h000002c8GrEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 8,
#   'ID_Student__c': 'a0A3h000002c8GsEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 9,
#   'ID_Student__c': 'a0A3h000002c8GtEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 10,
#   'ID_Student__c': 'a0A3h000002c8GuEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 11,
#   'ID_Student__c': 'a0A3h000002c8GvEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 12,
#   'ID_Student__c': 'a0A3h000002c8GwEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 13,
#   'ID_Student__c': 'a0A3h000002c8GzEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 14,
#   'ID_Student__c': 'a0A3h000002c8H0EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 15,
#   'ID_Student__c': 'a0A3h000002c8H1EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 16,
#   'ID_Student__c': 'a0A3h000002c8H2EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 17,
#   'ID_Student__c': 'a0A3h000002c8H3EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 18,
#   'ID_Student__c': 'a0A3h000002c8H4EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 20,
#   'ID_Student__c': 'a0A3h000002c8H6EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 21,
#   'ID_Student__c': 'a0A3h000002c8H7EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 22,
#   'ID_Student__c': 'a0A3h000002c8H8EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 23,
#   'ID_Student__c': 'a0A3h000002c8H9EAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 24,
#   'ID_Student__c': 'a0A3h000002c8HAEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 25,
#   'ID_Student__c': 'a0A3h000002c8HBEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 26,
#   'ID_Student__c': 'a0A3h000002c8HCEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 27,
#   'ID_Student__c': 'a0A3h000002c8HDEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 28,
#   'ID_Student__c': 'a0A3h000002c8HEEAY',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 29,
#   'ID_Student__c': 'a0A3h000002c8GxEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None}]

# %%
#Inserting rows in bulk

# %%
try:
    sf.bulk.ClassParticipant__c.insert(participant_load)
except Exception as e:
    print(e)

# %% [markdown]
# # Staff

# %%
staff_data = pd.read_sql("SELECT * FROM staff", conn)
staff_data.head(5)
# Out:
#    ID_Staff EmployeeID  LastName  FirstName MiddleName   BirthDate
# 0         1  000184220  Wimberly        Sam       Nico  1995-07-05
# 1         2  000130109   Sanford     Gemini      Blair  1992-04-22
# 2         3  000160655  Williams  Dartanion  De Angelo  1993-05-21
# 3         4  000159108   Popelka      Sarah      Nisan  1994-06-07

# %%
#staff_data['FullName'] = staff_data['FirstName'].str.cat(staff_data['LastName'], sep=" ")
staff_data=staff_data.rename(columns={"ID_Staff":"Name","EmployeeID":"EmployeeID__c","LastName":"LastName__c",
                                       "FirstName":"FirstName__c","MiddleName":"MiddleName__c",
                                      "BirthDate":"BirthDate__c"})
#convert date to string otherwise we will get JSON nonserilizable error
staff_data["BirthDate__c"]=staff_data["BirthDate__c"].astype(str)
staff_data.head()
# Out:
#    Name EmployeeID__c LastName__c FirstName__c MiddleName__c BirthDate__c
# 0     1     000184220    Wimberly          Sam          Nico   1995-07-05
# 1     2     000130109     Sanford       Gemini         Blair   1992-04-22
# 2     3     000160655    Williams    Dartanion     De Angelo   1993-05-21
# 3     4     000159108     Popelka        Sarah         Nisan   1994-06-07

# %%
#staff_data['FullName'] = staff_data['FirstName'].str.cat(staff_data['LastName'], sep=" ")
staff_data=staff_data.rename(columns={"ID_Staff":"ID_Staff__c","EmployeeID":"EmployeeID__c","LastName":"Name",
                                       "FirstName":"FirstName__c","MiddleName":"MiddleName__c",
                                      "BirthDate":"BirthDate__c"})
#convert date to string otherwise we will get JSON nonserilizable error
staff_data["BirthDate__c"]=staff_data["BirthDate__c"].astype(str)
staff_data.head()
# Out:
#    Name EmployeeID__c LastName__c FirstName__c MiddleName__c BirthDate__c
# 0     1     000184220    Wimberly          Sam          Nico   1995-07-05
# 1     2     000130109     Sanford       Gemini         Blair   1992-04-22
# 2     3     000160655    Williams    Dartanion     De Angelo   1993-05-21
# 3     4     000159108     Popelka        Sarah         Nisan   1994-06-07

# %%
staff_load = staff_data.to_dict('records')
staff_load
# Out:
# [{'Name': 1,
#   'EmployeeID__c': '000184220',
#   'LastName__c': 'Wimberly',
#   'FirstName__c': 'Sam',
#   'MiddleName__c': 'Nico',
#   'BirthDate__c': '1995-07-05'},
#  {'Name': 2,
#   'EmployeeID__c': '000130109',
#   'LastName__c': 'Sanford',
#   'FirstName__c': 'Gemini',
#   'MiddleName__c': 'Blair',
#   'BirthDate__c': '1992-04-22'},
#  {'Name': 3,
#   'EmployeeID__c': '000160655',
#   'LastName__c': 'Williams',
#   'FirstName__c': 'Dartanion',
#   'MiddleName__c': 'De Angelo',
#   'BirthDate__c': '1993-05-21'},
#  {'Name': 4,
#   'EmployeeID__c': '000159108',
#   'LastName__c': 'Popelka',
#   'FirstName__c': 'Sarah',
#   'MiddleName__c': 'Nisan',
#   'BirthDate__c': '1994-06-07'}]

# %%
try:
    sf.bulk.Staff__c.insert(staff_load)
except Exception as e:
    print(e)

# %% [markdown]
# # Staff Assignment

# %%
staffassignment_data = pd.read_sql("SELECT * FROM staffassignment", conn)
staffassignment_data
# Out:
#    ID_StaffAssignment  ID_Staff  ID_Class               Role   StartDate  \
# 0                   1         1         1  Teacher Assistant  2020-03-16
# 1                   2         4         1  Teacher Assistant  2020-03-16
# 2                   3         3         1         Instructor  2020-03-16
#
#   EndDate
# 0    None
# 1    None
# 2    None

# %% [markdown]
# ## Rename Columns

# %%
staffassignment_data=staffassignment_data.rename(columns={"ID_StaffAssignment":"Name",
                                                          "ID_Staff":"ID_Staff__c", "ID_Class":"ID_Class__c","Role":"Role__c",
                                                           "StartDate":"StartDate__c","EndDate":"EndDate__c"})
#convert date to string otherwise we will get JSON nonserilizable error
staffassignment_data["StartDate__c"]=staffassignment_data["StartDate__c"].astype(str)

staffassignment_data.head()
# Out:
#    Name  ID_Staff__c  ID_Class__c            Role__c StartDate__c EndDate__c
# 0     1            1            1  Teacher Assistant   2020-03-16       None
# 1     2            4            1  Teacher Assistant   2020-03-16       None
# 2     3            3            1         Instructor   2020-03-16       None

# %% [markdown]
# ## Convert DataFrame to a list of Dictionaries

# %%
staff_query=sf.query("SELECT Name from Staff__c")

# %%
staff_query
# Out:
# OrderedDict([('totalSize', 4),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Staff__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Staff__c/a0I3h0000007dPnEAI')])),
#                             ('Name', '1')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Staff__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Staff__c/a0I3h0000007dPoEAI')])),
#                             ('Name', '2')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Staff__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Staff__c/a0I3h0000007dPpEAI')])),
#                             ('Name', '3')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Staff__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Staff__c/a0I3h0000007dPqEAI')])),
#                             ('Name', '4')])])])

# %%
staff_dict={}
x=0
while x< len(staff_query['records']):
    url=staff_query['records'][x]['attributes']['url'].split('/')[6]
    staff_id=int(staff_query['records'][x]['Name'])
    print(url,staff_id)
    staff_dict[staff_id]=url
    x=x+1
print(staff_dict)
# Out:
# a0I3h0000007dPnEAI 1
# a0I3h0000007dPoEAI 2
# a0I3h0000007dPpEAI 3
# a0I3h0000007dPqEAI 4
# {1: 'a0I3h0000007dPnEAI', 2: 'a0I3h0000007dPoEAI', 3: 'a0I3h0000007dPpEAI', 4: 'a0I3h0000007dPqEAI'}

# %%
for index,row in staffassignment_data.iterrows():
    try:
        staffassignment_data['ID_Staff__c'][index]=staff_dict[row['ID_Staff__c']]
    except KeyError as e:
        print(e)
staffassignment_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Name         ID_Staff__c  ID_Class__c            Role__c StartDate__c  \
# 0     1  a0I3h0000007dPnEAI            1  Teacher Assistant   2020-03-16
# 1     2  a0I3h0000007dPqEAI            1  Teacher Assistant   2020-03-16
# 2     3  a0I3h0000007dPpEAI            1         Instructor   2020-03-16
#
#   EndDate__c
# 0       None
# 1       None
# 2       None

# %%
class_query=sf.query("SELECT Name from class__c")
class_query
# Out:
# OrderedDict([('totalSize', 4),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSZEAY')])),
#                             ('Name', '1')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSaEAI')])),
#                             ('Name', '2')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uSbEAI')])),
#                             ('Name', '3')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'class__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/class__c/a0F3h0000026uScEAI')])),
#                             ('Name', '4')])])])

# %%
class_dict={}
x=0
while x< len(class_query['records']):
    url=class_query['records'][x]['attributes']['url'].split('/')[6]
    class_id=int(class_query['records'][x]['Name'])
    print(url,class_id)
    class_dict[class_id]=url
    x=x+1
print(class_dict)
# Out:
# a0F3h0000026uSZEAY 1
# a0F3h0000026uSaEAI 2
# a0F3h0000026uSbEAI 3
# a0F3h0000026uScEAI 4
# {1: 'a0F3h0000026uSZEAY', 2: 'a0F3h0000026uSaEAI', 3: 'a0F3h0000026uSbEAI', 4: 'a0F3h0000026uScEAI'}

# %%
for index,row in staffassignment_data.iterrows():
    staffassignment_data['ID_Class__c'][index]=class_dict[row['ID_Class__c']]
staffassignment_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Name         ID_Staff__c         ID_Class__c            Role__c  \
# 0     1  a0I3h0000007dPnEAI  a0F3h0000026uSZEAY  Teacher Assistant
# 1     2  a0I3h0000007dPqEAI  a0F3h0000026uSZEAY  Teacher Assistant
# 2     3  a0I3h0000007dPpEAI  a0F3h0000026uSZEAY         Instructor
#
#   StartDate__c EndDate__c
# 0   2020-03-16       None
# 1   2020-03-16       None
# 2   2020-03-16       None

# %%
staffassignment_load = staffassignment_data.to_dict('records')
staffassignment_load
# Out:
# [{'Name': 1,
#   'ID_Staff__c': 'a0I3h0000007dPnEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'Role__c': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 2,
#   'ID_Staff__c': 'a0I3h0000007dPqEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'Role__c': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 3,
#   'ID_Staff__c': 'a0I3h0000007dPpEAI',
#   'ID_Class__c': 'a0F3h0000026uSZEAY',
#   'Role__c': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None}]

# %% [markdown]
# ## Inserting rows in bulk

# %%
try:
    sf.bulk.StaffAssignment__c.insert(staffassignment_load)
except Exception as e:
    print(e)
