# %%
#!pip install simple_salesforce #allows us to work with salesforce API

# %%
import os
orig_working_directory=os.getcwd()
orig_working_directory
# Out:
# 'C:\\Users\\clemi\\Desktop\\Clementine-GWU-HW\\ETL_Project'

# %%
os.chdir(os.path.join('..'))
curr_working_directory=os.getcwd()
curr_working_directory
# Out:
# 'C:\\Users\\clemi\\Desktop\\Clementine-GWU-HW'

# %% [markdown]
# ## Import Dependencies

# %%
import json
from sqlalchemy import create_engine
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ## Import configuration variables

# %%
from salesforce_config import sf_username, sf_password, sf_security_token
from salesforce_config import remote_db_endpoint, remote_db_port
from salesforce_config import remote_db_name, remote_db_user, remote_db_pwd

# %% [markdown]
# ## Set up simple_salesforce

# %%
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %% [markdown]
# ## Connect to your MySQL database

# %%
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %% [markdown]
# ## Query Data

# %%
student_data = pd.read_sql("SELECT * FROM student", conn)
student_data.head(5)
# Out:
#    ID_Student StudentID    LastName  FirstName MiddleName BirthDate Gender
# 0          33  25004961       Moore    Heather      Alice      None      F
# 1          34  25003514      Multak      Ilana    Cecille      None      F
# 2          35  25005833     Murillo    Jessica    Dorothy      None      F
# 3          36  25002589  Romanowski     Kandra  Genevieve      None      F
# 4          37  25007185      Hoffer  Katherine   Lynnette      None      F

# %% [markdown]
# ## Transform Data

# %%
#student_data['FullName'] = student_data['FirstName'].str.cat(student_data['LastName'], sep=" ")
student_data=student_data.rename(columns={"ID_Student":"ID_Student__c","StudentID":"StudentID__c","LastName":"Name",
                                       "FirstName":"FirstName__c","MiddleName":"MiddleName__c","Gender":"Gender__c",
                                        "BirthDate":"BirthDate__c"})
student_data.head(5)
# Out:
#    ID_Student__c StudentID__c        Name FirstName__c MiddleName__c  \
# 0             33     25004961       Moore      Heather         Alice
# 1             34     25003514      Multak        Ilana       Cecille
# 2             35     25005833     Murillo      Jessica       Dorothy
# 3             36     25002589  Romanowski       Kandra     Genevieve
# 4             37     25007185      Hoffer    Katherine      Lynnette
#
#   BirthDate__c Gender__c
# 0         None         F
# 1         None         F
# 2         None         F
# 3         None         F
# 4         None         F

# %% [markdown]
# ## Convert DataFrame to a list of Dictionaries

# %%
student_load = student_data.to_dict('records')
student_load
# Out:
# [{'ID_Student__c': 33,
#   'StudentID__c': '25004961',
#   'Name': 'Moore',
#   'FirstName__c': 'Heather',
#   'MiddleName__c': 'Alice',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 34,
#   'StudentID__c': '25003514',
#   'Name': 'Multak',
#   'FirstName__c': 'Ilana',
#   'MiddleName__c': 'Cecille',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 35,
#   'StudentID__c': '25005833',
#   'Name': 'Murillo',
#   'FirstName__c': 'Jessica',
#   'MiddleName__c': 'Dorothy',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 36,
#   'StudentID__c': '25002589',
#   'Name': 'Romanowski',
#   'FirstName__c': 'Kandra',
#   'MiddleName__c': 'Genevieve',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 37,
#   'StudentID__c': '25007185',
#   'Name': 'Hoffer',
#   'FirstName__c': 'Katherine',
#   'MiddleName__c': 'Lynnette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 38,
#   'StudentID__c': '25006014',
#   'Name': 'Poocharoen',
#   'FirstName__c': 'Pariya',
#   'MiddleName__c': 'Mariette',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 39,
#   'StudentID__c': '25007528',
#   'Name': 'Mantrala',
#   'FirstName__c': 'Sriharitha',
#   'MiddleName__c': 'Patty',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 40,
#   'StudentID__c': '25003778',
#   'Name': 'Kelly',
#   'FirstName__c': 'Carly',
#   'MiddleName__c': 'Raelene',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 41,
#   'StudentID__c': '25003605',
#   'Name': 'Sraha',
#   'FirstName__c': 'Clementine',
#   'MiddleName__c': 'Kendall',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 42,
#   'StudentID__c': '25002056',
#   'Name': 'Abdulrahim',
#   'FirstName__c': 'Jawaher',
#   'MiddleName__c': 'Angela',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 43,
#   'StudentID__c': '25004152',
#   'Name': 'Schulte',
#   'FirstName__c': 'Sarah',
#   'MiddleName__c': 'Serita',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 44,
#   'StudentID__c': '25004097',
#   'Name': 'Damdinsuren',
#   'FirstName__c': 'Undraa',
#   'MiddleName__c': 'Claire',
#   'BirthDate__c': None,
#   'Gender__c': 'F'},
#  {'ID_Student__c': 45,
#   'StudentID__c': '25002311',
#   'Name': 'Smith',
#   'FirstName__c': 'James',
#   'MiddleName__c': 'Carlton',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 46,
#   'StudentID__c': '25005602',
#   'Name': 'Martinez',
#   'FirstName__c': 'Joisel',
#   'MiddleName__c': 'Cyrus',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 47,
#   'StudentID__c': '25006805',
#   'Name': 'Odhiambo',
#   'FirstName__c': 'Pius',
#   'MiddleName__c': 'Danny',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 48,
#   'StudentID__c': '25006947',
#   'Name': 'Karr',
#   'FirstName__c': 'Todd',
#   'MiddleName__c': 'Darren',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 49,
#   'StudentID__c': '25002714',
#   'Name': 'Stark',
#   'FirstName__c': 'Tom',
#   'MiddleName__c': 'Deangelo',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 50,
#   'StudentID__c': '25005284',
#   'Name': 'Mahmood',
#   'FirstName__c': 'Adit',
#   'MiddleName__c': 'Dion',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 51,
#   'StudentID__c': '25006348',
#   'Name': 'Mikus',
#   'FirstName__c': 'Chris',
#   'MiddleName__c': 'Floyd',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 52,
#   'StudentID__c': '25002555',
#   'Name': 'Hanafin',
#   'FirstName__c': 'Christopher',
#   'MiddleName__c': 'Horace',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 53,
#   'StudentID__c': '25005250',
#   'Name': 'Fingerut',
#   'FirstName__c': 'Cole',
#   'MiddleName__c': 'Lino',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 54,
#   'StudentID__c': '25002325',
#   'Name': 'Hoff',
#   'FirstName__c': 'David',
#   'MiddleName__c': 'Lucien',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 55,
#   'StudentID__c': '25003773',
#   'Name': 'Molina',
#   'FirstName__c': 'Dino',
#   'MiddleName__c': 'Lynwood',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 56,
#   'StudentID__c': '25003936',
#   'Name': 'Vega',
#   'FirstName__c': 'John',
#   'MiddleName__c': 'Noelle',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 57,
#   'StudentID__c': '25005443',
#   'Name': 'Clarke',
#   'FirstName__c': 'Michael',
#   'MiddleName__c': 'Parker',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 58,
#   'StudentID__c': '25006762',
#   'Name': 'Huynh',
#   'FirstName__c': 'Patrick',
#   'MiddleName__c': 'Richard',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 59,
#   'StudentID__c': '25006027',
#   'Name': 'Oppan',
#   'FirstName__c': 'Robert',
#   'MiddleName__c': 'Riley',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 60,
#   'StudentID__c': '25002876',
#   'Name': 'Doucet',
#   'FirstName__c': 'Trevor',
#   'MiddleName__c': 'Seth',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 61,
#   'StudentID__c': '25007333',
#   'Name': 'Omar',
#   'FirstName__c': 'Yasir',
#   'MiddleName__c': 'Solomon',
#   'BirthDate__c': None,
#   'Gender__c': 'M'},
#  {'ID_Student__c': 62,
#   'StudentID__c': '25007334',
#   'Name': 'Williamson',
#   'FirstName__c': 'Kevin',
#   'MiddleName__c': 'Stewart',
#   'BirthDate__c': None,
#   'Gender__c': 'M'}]

# %% [markdown]
# ### Inserting rows in bulk

# %%
try:
    sf.bulk.Student__c.insert(student_load) #Student__c is the API name
except Exception as e:
    print(e)

# %% [markdown]
# ## Class Participant

# %% [markdown]
# ### Query Data

# %%
participant_data = pd.read_sql("SELECT * FROM classparticipant", conn)
participant_data.head(30)
# Out:
#     ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate
# 0                     1          33         1  2020-03-16    None
# 1                     2          34         1  2020-03-16    None
# 2                     3          35         1  2020-03-16    None
# 3                     4          62         1  2020-03-16    None
# 4                     5          36         1  2020-03-16    None
# 5                     6          37         1  2020-03-16    None
# 6                     7          38         1  2020-03-16    None
# 7                     8          39         1  2020-03-16    None
# 8                     9          40         1  2020-03-16    None
# 9                    10          41         1  2020-03-16    None
# 10                   11          42         1  2020-03-16    None
# 11                   12          43         1  2020-03-16    None
# 12                   13          46         1  2020-03-16    None
# 13                   14          47         1  2020-03-16    None
# 14                   15          48         1  2020-03-16    None
# 15                   16          49         1  2020-03-16    None
# 16                   17          50         1  2020-03-16    None
# 17                   18          51         1  2020-03-16    None
# 18                   20          53         1  2020-03-16    None
# 19                   21          54         1  2020-03-16    None
# 20                   22          55         1  2020-03-16    None
# 21                   23          56         1  2020-03-16    None
# 22                   24          57         1  2020-03-16    None
# 23                   25          58         1  2020-03-16    None
# 24                   26          59         1  2020-03-16    None
# 25                   27          60         1  2020-03-16    None
# 26                   28          61         1  2020-03-16    None
# 27                   29          44         1  2020-03-16    None

# %% [markdown]
# ### Rename Columns

# %%
participant_data=participant_data.rename(columns={"ID_ClassParticipant":"Name","ID_Student":"ID_Student__c",
                                        "ID_Class":"ID_Class__c","StartDate":"StartDate__c","EndDate":"EndDate__c"})
#convert date to string otherwise we will get JSON nonserilizable error
participant_data["StartDate__c"]=participant_data["StartDate__c"].astype(str)
participant_data.head()
# Out:
#    Name  ID_Student__c  ID_Class__c StartDate__c EndDate__c
# 0     1             33            1   2020-03-16       None
# 1     2             34            1   2020-03-16       None
# 2     3             35            1   2020-03-16       None
# 3     4             62            1   2020-03-16       None
# 4     5             36            1   2020-03-16       None

# %% [markdown]
# ### Extract Record ID

# %%
query=sf.query("SELECT ID_Student__c from Student__c")

# %%
query
# Out:
# OrderedDict([('totalSize', 30),
#              ('done', True),
#              ('records',
#               [OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SBEAY')])),
#                             ('ID_Student__c', '33')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SCEAY')])),
#                             ('ID_Student__c', '34')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SDEAY')])),
#                             ('ID_Student__c', '35')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SEEAY')])),
#                             ('ID_Student__c', '36')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SFEAY')])),
#                             ('ID_Student__c', '37')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SGEAY')])),
#                             ('ID_Student__c', '38')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SHEAY')])),
#                             ('ID_Student__c', '39')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SIEAY')])),
#                             ('ID_Student__c', '40')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SJEAY')])),
#                             ('ID_Student__c', '41')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SKEAY')])),
#                             ('ID_Student__c', '42')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SLEAY')])),
#                             ('ID_Student__c', '43')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SMEAY')])),
#                             ('ID_Student__c', '44')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SNEAY')])),
#                             ('ID_Student__c', '45')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SOEAY')])),
#                             ('ID_Student__c', '46')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SPEAY')])),
#                             ('ID_Student__c', '47')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SQEAY')])),
#                             ('ID_Student__c', '48')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SREAY')])),
#                             ('ID_Student__c', '49')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SSEAY')])),
#                             ('ID_Student__c', '50')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6STEAY')])),
#                             ('ID_Student__c', '51')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SUEAY')])),
#                             ('ID_Student__c', '52')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SVEAY')])),
#                             ('ID_Student__c', '53')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SWEAY')])),
#                             ('ID_Student__c', '54')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SXEAY')])),
#                             ('ID_Student__c', '55')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SYEAY')])),
#                             ('ID_Student__c', '56')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SZEAY')])),
#                             ('ID_Student__c', '57')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SaEAI')])),
#                             ('ID_Student__c', '58')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SbEAI')])),
#                             ('ID_Student__c', '59')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6ScEAI')])),
#                             ('ID_Student__c', '60')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SdEAI')])),
#                             ('ID_Student__c', '61')]),
#                OrderedDict([('attributes',
#                              OrderedDict([('type', 'Student__c'),
#                                           ('url',
#                                            '/services/data/v42.0/sobjects/Student__c/a0A3h000002c6SeEAI')])),
#                             ('ID_Student__c', '62')])])])

# %% [markdown]
# ### Extract Student table record numbers

# %%
student_dict={}
x=0
while x< len(query['records']):
    url=query['records'][x]['attributes']['url'].split('/')[6]
    student_id=int(query['records'][x]['ID_Student__c'])
    print(url,student_id)
    student_dict[student_id]=url
    x=x+1
print(student_dict)
# Out:
# a0A3h000002c6SBEAY 33
# a0A3h000002c6SCEAY 34
# a0A3h000002c6SDEAY 35
# a0A3h000002c6SEEAY 36
# a0A3h000002c6SFEAY 37
# a0A3h000002c6SGEAY 38
# a0A3h000002c6SHEAY 39
# a0A3h000002c6SIEAY 40
# a0A3h000002c6SJEAY 41
# a0A3h000002c6SKEAY 42
# a0A3h000002c6SLEAY 43
# a0A3h000002c6SMEAY 44
# a0A3h000002c6SNEAY 45
# a0A3h000002c6SOEAY 46
# a0A3h000002c6SPEAY 47
# a0A3h000002c6SQEAY 48
# a0A3h000002c6SREAY 49
# a0A3h000002c6SSEAY 50
# a0A3h000002c6STEAY 51
# a0A3h000002c6SUEAY 52
# a0A3h000002c6SVEAY 53
# a0A3h000002c6SWEAY 54
# a0A3h000002c6SXEAY 55
# a0A3h000002c6SYEAY 56
# a0A3h000002c6SZEAY 57
# a0A3h000002c6SaEAI 58
# a0A3h000002c6SbEAI 59
# a0A3h000002c6ScEAI 60
# a0A3h000002c6SdEAI 61
# a0A3h000002c6SeEAI 62
# {33: 'a0A3h000002c6SBEAY', 34: 'a0A3h000002c6SCEAY', 35: 'a0A3h000002c6SDEAY', 36: 'a0A3h000002c6SEEAY', 37: 'a0A3h000002c6SFEAY', 38: 'a0A3h000002c6SGEAY', 39: 'a0A3h000002c6SHEAY', 40: 'a0A3h000002c6SIEAY', 41: 'a0A3h000002c6SJEAY', 42: 'a0A3h000002c6SKEAY', 43: 'a0A3h000002c6SLEAY', 44: 'a0A3h000002c6SMEAY', 45: 'a0A3h000002c6SNEAY', 46: 'a0A3h000002c6SOEAY', 47: 'a0A3h000002c6SPEAY', 48: 'a0A3h000002c6SQEAY', 49: 'a0A3h000002c6SREAY', 50: 'a0A3h000002c6SSEAY', 51: 'a0A3h000002c6STEAY', 52: 'a0A3h000002c6SUEAY', 53: 'a0A3h000002c6SVEAY', 54: 'a0A3h000002c6SWEAY', 55: 'a0A3h000002c6SXEAY', 56: 'a0A3h000002c6SYEAY', 57: 'a0A3h000002c6SZEAY', 58: 'a0A3h000002c6SaEAI', 59: 'a0A3h000002c6SbEAI', 60: 'a0A3h000002c6ScEAI', 61: 'a0A3h000002c6SdEAI', 62: 'a0A3h000002c6SeEAI'}

# %%
for index,row in participant_data.iterrows():
    participant_data['ID_Student__c'][index]=student_dict[row['ID_Student__c']]
participant_data
# Out:
# C:\Users\clemi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\clemi\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#     Name       ID_Student__c  ID_Class__c StartDate__c EndDate__c
# 0      1  a0A3h000002c6SBEAY            1   2020-03-16       None
# 1      2  a0A3h000002c6SCEAY            1   2020-03-16       None
# 2      3  a0A3h000002c6SDEAY            1   2020-03-16       None
# 3      4  a0A3h000002c6SeEAI            1   2020-03-16       None
# 4      5  a0A3h000002c6SEEAY            1   2020-03-16       None
# 5      6  a0A3h000002c6SFEAY            1   2020-03-16       None
# 6      7  a0A3h000002c6SGEAY            1   2020-03-16       None
# 7      8  a0A3h000002c6SHEAY            1   2020-03-16       None
# 8      9  a0A3h000002c6SIEAY            1   2020-03-16       None
# 9     10  a0A3h000002c6SJEAY            1   2020-03-16       None
# 10    11  a0A3h000002c6SKEAY            1   2020-03-16       None
# 11    12  a0A3h000002c6SLEAY            1   2020-03-16       None
# 12    13  a0A3h000002c6SOEAY            1   2020-03-16       None
# 13    14  a0A3h000002c6SPEAY            1   2020-03-16       None
# 14    15  a0A3h000002c6SQEAY            1   2020-03-16       None
# 15    16  a0A3h000002c6SREAY            1   2020-03-16       None
# 16    17  a0A3h000002c6SSEAY            1   2020-03-16       None
# 17    18  a0A3h000002c6STEAY            1   2020-03-16       None
# 18    20  a0A3h000002c6SVEAY            1   2020-03-16       None
# 19    21  a0A3h000002c6SWEAY            1   2020-03-16       None
# 20    22  a0A3h000002c6SXEAY            1   2020-03-16       None
# 21    23  a0A3h000002c6SYEAY            1   2020-03-16       None
# 22    24  a0A3h000002c6SZEAY            1   2020-03-16       None
# 23    25  a0A3h000002c6SaEAI            1   2020-03-16       None
# 24    26  a0A3h000002c6SbEAI            1   2020-03-16       None
# 25    27  a0A3h000002c6ScEAI            1   2020-03-16       None
# 26    28  a0A3h000002c6SdEAI            1   2020-03-16       None
# 27    29  a0A3h000002c6SMEAY            1   2020-03-16       None

# %%
query=sf.query("SELECT ID_Class__c from Class__c")

# %%
student_dict={}
x=0
while x< len(query['records']):
    url=query['records'][x]['attributes']['url'].split('/')[6]
    student_id=int(query['records'][x]['ID_Student__c'])
    print(url,student_id)
    student_dict[student_id]=url
    x=x+1
print(student_dict)

# %% [markdown]
# ### Convert Dataframe to list of dictionaries

# %%
participant_load = participant_data.to_dict('records')
participant_load
# Out:
# [{'Name': 1,
#   'ID_Student__c': 'a0A3h000002c6SBEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 2,
#   'ID_Student__c': 'a0A3h000002c6SCEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 3,
#   'ID_Student__c': 'a0A3h000002c6SDEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 4,
#   'ID_Student__c': 'a0A3h000002c6SeEAI',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 5,
#   'ID_Student__c': 'a0A3h000002c6SEEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 6,
#   'ID_Student__c': 'a0A3h000002c6SFEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 7,
#   'ID_Student__c': 'a0A3h000002c6SGEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 8,
#   'ID_Student__c': 'a0A3h000002c6SHEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 9,
#   'ID_Student__c': 'a0A3h000002c6SIEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 10,
#   'ID_Student__c': 'a0A3h000002c6SJEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 11,
#   'ID_Student__c': 'a0A3h000002c6SKEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 12,
#   'ID_Student__c': 'a0A3h000002c6SLEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 13,
#   'ID_Student__c': 'a0A3h000002c6SOEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 14,
#   'ID_Student__c': 'a0A3h000002c6SPEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 15,
#   'ID_Student__c': 'a0A3h000002c6SQEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 16,
#   'ID_Student__c': 'a0A3h000002c6SREAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 17,
#   'ID_Student__c': 'a0A3h000002c6SSEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 18,
#   'ID_Student__c': 'a0A3h000002c6STEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 20,
#   'ID_Student__c': 'a0A3h000002c6SVEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 21,
#   'ID_Student__c': 'a0A3h000002c6SWEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 22,
#   'ID_Student__c': 'a0A3h000002c6SXEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 23,
#   'ID_Student__c': 'a0A3h000002c6SYEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 24,
#   'ID_Student__c': 'a0A3h000002c6SZEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 25,
#   'ID_Student__c': 'a0A3h000002c6SaEAI',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 26,
#   'ID_Student__c': 'a0A3h000002c6SbEAI',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 27,
#   'ID_Student__c': 'a0A3h000002c6ScEAI',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 28,
#   'ID_Student__c': 'a0A3h000002c6SdEAI',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None},
#  {'Name': 29,
#   'ID_Student__c': 'a0A3h000002c6SMEAY',
#   'ID_Class__c': 1,
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None}]

# %% [markdown]
# ### Inserting rows in bulk

# %%
try:
    sf.bulk.ClassParticipant__c.insert(participant_load)
except Exception as e:
    print(e)

# %% [markdown]
# # Course

# %%
course_data = pd.read_sql("SELECT * FROM course", conn)
course_data.head(30)
# Out:
#    ID_Course  CourseCode                        CourseName  CreditHours  \
# 0          1  BC-DATAVIZ  Data Visualization and Analytics           12
# 1          2   BC-WEBDEV        Full Stack Web Development           12
# 2          3     BC-UIUX    User Interface/User Experience           12
# 3          4     CIS-349         Introduction to Databases            5
# 4          5     CIS-405              Database Programming            5
# 5          6     CIS-438           Database Administration            5
# 6          7     CIS-430    Business Systems Programming I            5
# 7          8     CIS-435   Business Systems Programming II            5
#
#    BootCampCourse
# 0               1
# 1               1
# 2               1
# 3               0
# 4               0
# 5               0
# 6               0
# 7               0

# %%
course_data=course_data.rename(columns={"ID_Course":"ID_Course__c","CourseCode":"CourseCode__c","CourseName":"Name",
                                       "CreditHours":"CreditHours__c","BootCampCourse":"BootCampCourse__c"})
course_data.head()

# %%
course_load = course_data.to_dict('records')
course_load

# %%
try:
    sf.bulk.Course__c.insert(course_load)
except Exception as e:
    print(e)

# %% [markdown]
# # Class

# %%
class_data = pd.read_sql("SELECT * FROM class", conn)
class_data.head(5)

# %%
class_data=class_data.rename(columns={"ID_Class":"ID_Class__c","ID_Course":"ID_Course__c","Section":"Name",
                                      "StartDate":"StartDate__c","EndDate":"EndDate__c"})

class_data.head(5)

# %%
class_data["StartDate__c"]=class_data["StartDate__c"].astype(str)
class_data["EndDate__c"]=class_data["EndDate__c"].astype(str)

# %%
course_query=sf.query("SELECT ID_Course__c from Course__c")

course_query

# %%
course_dict={}
x=0
while x< len(course_query['records']):
    url=course_query['records'][x]['attributes']['url'].split('/')[6]
    course_id=int(course_query['records'][x]['ID_Course__c'])
    print(url,course_id)
    course_dict[course_id]=url
    x=x+1
print(course_dict)

# %%
for index,row in class_data.iterrows():
    class_data['ID_Course__c'][index]=course_dict[row['ID_Course__c']]
class_data

# %%
participant_query=sf.query("SELECT ID_Class__c from ClassParticipant__c")

participant_query

# %%
participant_dict={}
x=0
while x< len(participant_query['records']):
    url=participant_query['records'][x]['attributes']['url'].split('/')[6]
    participant_id=int(participant_query['records'][x]['ID_Class__c'])
    print(url,participant_id)
    participant_dict[participant_id]=url
    x=x+1
print(participant_dict)

# %%
for index,row in class_data.iterrows():
    try:
        class_data['ID_Class__c'][index]=participant_dict[row['ID_Class__c']]
    except KeyError as e:
        print(e)
class_data

# %%
class_load = class_data.to_dict('records')
class_load

# %%
try:
    sf.bulk.Class__c.insert(class_load)
except Exception as e:
    print(e)
